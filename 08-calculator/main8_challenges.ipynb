# %% [markdown]
# ## 🚀 Challenge Projects

# %% [markdown]
# ### Challenge 1: Multi-Step Calculator

# %%
# Create a multi-step calculator program with the following features:
# 1. display a menu of operations (add, subtract, multiply, divide)
# 2. ask the user to select an first operation
# 3. user input - get data (numbers) > with error handling
# 4. perform the calculation
# 5. ask the user to select an second operation (optional) > if the user selects an operation, repeat steps 3-4 with the result of the previous calculation as the first number 
# 6. add the calculation to history
# 7. display the history
# 8. allow the user to exit the program

# 1. display a menu of operations (add, subtract, multiply, divide)
print("== Welcome to the Calculator! ==")
print("Select the 1st operation:")
print("1. Add (+)")
print("2. Subtract (-)")
print("3. Multiply (*)")
print("4. Divide (/)")
print("5. Exit")

# 2. ask the user to select an first operation
history = []   # to store calculation history

while True:
    #TODO: -- first operation --
    opr1 = input("Enter the number corresponding to the operation (1-5): ")
    
    if opr1 == '5':
        print("Break the loop (upper) => Goodbye!")
        break
    
    if opr1 not in ['1', '2', '3', '4']:
        print("Invalid selection. Please try again.")
        continue
    
    # 3. user input - get data (numbers) > with error handling
    try:
        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))
    except ValueError:
        print("Invalid input. Please enter numeric values.")
        continue
    
    # 4. perform the calculation
    if opr1 == '1':
        result1 = num1 + num2
    elif opr1 == '2':
        result1 = num1 - num2
    elif opr1 == '3':
        result1 = num1 * num2
    elif opr1 == '4':
        if num2 == 0:
            print("Error: Division by zero is not allowed.")
            continue
        result1 = num1 / num2

    # 5. Display the selected 1st operator 
    # - using a 'dictionary' to map the operator number to its symbol 
    print(f"# Selected operator (1st): {'+' if opr1 == '1' else '-' if opr1 == '2' else '*' if opr1 == '3' else '/'}")
    # Display the result of the first operation
    print(f"--Result (1st operation): {result1}")
    print()  # print a blank line for better readability

    #TODO: -- second operation --
    # 6. ask the user to select an second operation (optional) 
    # - if the user selects an operation, repeat steps 3-4 
    # - with the result of the previous calculation as the first number
    print("Select the 2nd operation (optional):")
    print("1. Add (+)")
    print("2. Subtract (-)")
    print("3. Multiply (*)")
    print("4. Divide (/)")
    print("5. No further operation")
    
    opr2 = input("Enter the number corresponding to the operation (1-5): ")

    if opr2 == '5':
        result2 = result1
    elif opr2 in ['1', '2', '3', '4']:
        try:
            num3 = float(input("Enter the second number for the 2nd operation: "))
        except ValueError:
            print("Invalid input. Please enter a numeric value.")
            continue
        
        if opr2 == '1':
            result2 = result1 + num3
        elif opr2 == '2':
            result2 = result1 - num3
        elif opr2 == '3':
            result2 = result1 * num3
        elif opr2 == '4':
            if num3 == 0:
                print("Error: Division by zero is not allowed.")
                continue
            result2 = result1 / num3
    else:
        print("Invalid selection for the 2nd operation. Please try again.")
        continue

    # 7. Display the final result of the calculation
    if opr2 == '5':
        final_result = result1  # No further operation, use the result of the first operation as the final result
    else:
        final_result = result2  # Use the result of the second operation as the final result    
    
    # 8. Display the selected 2nd operator 
    # - using a 'dictionary' to map the operator number to its symbol
    opr_symbol = {'1': '+', '2': '-', '3': '*', '4': '/'}
    if opr2 in ['1', '2', '3', '4']:
        print(f"# Selected operator (2nd): {opr_symbol[opr2]}")

    print(f"--Final Result: {final_result}")
    print()  # print a blank line for better readability

    # 9. add the calculation to history
    if opr2 == '5':
        history.append(f"{num1} {opr_symbol[opr1]} {num2} = {final_result}")
    else:
        history.append(f"{num1} {opr_symbol[opr1]} {num2} {opr_symbol[opr2]} {num3} = {final_result}") 

    # 10. display all calc-history
    print("# Calculation History:")
    for i, calc in enumerate(history, start=1):
        print(f"{i}. {calc}")   
    print()

    # 11. ask the user if they want to run the calculator again
    run_again = input("Do you want to run the calculator again? (Y/N): ")
    if run_again.lower() != "y":
        print("Break the loop (last) => Goodbye!")
        break       #TODO: exit the loop

print("Exit the calculation => Hope it helpful!")
# Out:
# == Welcome to the Calculator! ==
# Select the 1st operation:
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (/)
# 5. Exit
# # Selected operator (1st): /
# --Result (1st operation): 11.0
#
# Select the 2nd operation (optional):
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (/)
# 5. No further operation
# # Selected operator (2nd): +
# --Final Result: 56.0
#
# # Calculation History:
# 1. 55.0 / 5.0 + 45.0 = 56.0
#
# # Selected operator (1st): *
# --Result (1st operation): 88.0
#
# Select the 2nd operation (optional):
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (/)
# 5. No further operation
# # Selected operator (2nd): *
# --Final Result: 352.0
#
# # Calculation History:
# 1. 55.0 / 5.0 + 45.0 = 56.0
# 2. 22.0 * 4.0 * 4.0 = 352.0
#
# Break the loop (last) => Goodbye!
# Exit the calculation => Hope it helpful!

# %%
    

    # Display the selected operator for the first operation
    opr_symbol = {'1': '+', '2': '-', '3': '*', '4': '/'}
    print(f"# Selected operator: {opr_symbol[opr1]}") 
    # Display the selected operator for the second operation if applicable
    if opr2 in ['1', '2', '3', '4']:
      print(f"# Selected operator for 2nd operation: {opr_symbol[opr2]}")

    # Display the final result of the calculation
    print(f"Result: {num1} {opr_symbol[opr1]} {num2}", end="")
    if opr2 in ['1', '2', '3', '4']:
        print(f" {opr_symbol[opr2]} {num3}", end="")
    print(f" = {final_result}")

    # Add the calculation to history
    if opr2 == '5':
        history.append(f"{num1} {opr_symbol[opr1]} {num2} = {result1}")
    else:
        history.append(f"{num1} {opr_symbol[opr1]} {num2} {opr_symbol[opr2]} {num3} = {final_result}") 

  # Display the calculation history
    print("# Calculation History:")
    for i, calc in enumerate(history, start=1):
        print(f"{i}. {calc}")
    
    # EX: Calculation History:
    # 1. 223.0 + 66.0 = 289.0
    # 2. 89.0 / 9.0 = 9.88888888888889
    
    print()

  # ! --- calculator code - end here ---

  # Note: The above code implements a multi-step calculator with error handling, calculation history, and the ability to perform a second operation on the result of the first operation. The user can exit the program at any time by selecting the exit option.

  # add more features as needed, such as allowing the user to clear the history, or to save the history to a file.

  # add a feature to allow the user to perform more than two operations in a sequence, by using a loop to continue asking for additional operations until the user decides to stop.

  # add a feature to allow the user to use the result of the previous calculation as the first number for the next calculation, without having to re-enter it.

  # add a feature to allow the user to use parentheses to specify the order of operations, and to handle more complex expressions.

  # add a feature to allow the user to use variables to store intermediate results, and to use those variables in subsequent calculations.

  # add a feature to exit the program
    exit_option = input("Do you want to exit the program? (yes/no): ")
    if exit_option.lower() == 'yes':
        print("Exiting the calculator. Goodbye!")
        break

# %% [markdown]
# ### Challenge 2: Unit Converter
